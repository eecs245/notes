# %% [markdown]
# # Chapter 6: Probability
#
# Eventually, this chapter will have 5 sections. As these sections are finished, they will be unveiled in the table of contents to the left, and linked directly on the [course website](https://eecs245.org) underneath any relevant lectures.
#
# 1. Random Variables
# 2. Continuous Distributions
# 3. Independence
# 4. Maximum Likelihood Estimation
# 5. Least Squares, Revisited, Again
