# %% [markdown]
# # Chapter 4: Gradients
#
# Eventually, this chapter will have 2 or 3 sections. As these sections are finished, they will be unveiled in the table of contents to the left, and linked directly on the [course website](https://eecs245.org) underneath any relevant lectures.
#
# 1. [The Gradient Vector](01-gradient-vector.ipynb)
# 2. Gradient Descent
