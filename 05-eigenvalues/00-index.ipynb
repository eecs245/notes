# %% [markdown]
# # Chapter 5: Eigenvalues and Eigenvectors
#
# Eventually, this chapter will have 4 sections. As these sections are finished, they will be unveiled in the table of contents to the left, and linked directly on the [course website](https://eecs245.org) underneath any relevant lectures.
#
# 1. Eigenvalues and Eigenvectors
# 2. Matrix Factorization
# 3. Singular Value Decomposition
# 4. Principal Components Analysis
