# %% [markdown]
# # Chapter 5: Eigenvalues and Eigenvectors
#
# Eventually, this chapter will have 3-4 sections. As these sections are finished, they will be unveiled in the table of contents to the left, and linked directly on the [course website](https://eecs245.org) underneath any relevant lectures.
#
# 1. [Eigenvalues and Eigenvectors](01-intro.ipynb) and [Part 2: Adjacency Matrices](015-adjacency-matrices.ipynb)
# 2. [Diagonalization](02-diagonalization.ipynb)
# 3. [Singular Value Decomposition](03-singular-value-decomposition.ipynb)
# 4. [Principal Components Analysis](04-principal-components-analysis.ipynb)
