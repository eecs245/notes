# %% [markdown]
# # Chapter 2: Vectors and Matrices
#
# Eventually, this chapter will have 10 sections. As these sections are finished, they will be unveiled in the table of contents to the left, and linked directly on the [course website](https://eecs245.org) underneath any relevant lectures.
#
# 1. [Vectors](01-vectors.ipynb)
# 2. [The Dot Product](02-dot-product.ipynb)
# 3. [Projection, Part 1](03-projection-1.ipynb)
# 4. [Span and Linear Independence](04-span-linear-independence.ipynb)
# 5. [Lines, Planes, and Hyperplanes](05-lines-planes-hyperplanes.ipynb)
# 6. [Vector Spaces](06-vector-spaces.ipynb)
# <!-- 5. Matrices
# 6. Rank and Vector Spaces
# 7. Inverses and Determinants
# 8. Projection, Part 2 -->
