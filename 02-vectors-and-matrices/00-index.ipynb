# %% [markdown]
# # Chapter 2: Vectors and Matrices
#
# Eventually, this chapter will have 8 sections. As these sections are finished, they will be unveiled in the table of contents to the left, and linked directly on the [course website](https://eecs245.org) underneath any relevant lectures.
#
# 1. [Vectors](01-vectors.ipynb)
# 2. The Dot Product
# 3. Projection, Part 1
# 4. Linear Independence
# 5. Matrices
# 6. Rank and Vector Spaces
# 7. Inverses and Determinants
# 8. Projection, Part 2
