# %% [markdown]
# # Chapter 1: Introduction to Supervised Learning
#
# This chapter has 5 sections. As these sections are finished, they will be unveiled in the table of contents to the left, and linked directly on the [course website](https://eecs245.org) underneath any relevant lectures.
#
# 1. [What is Machine Learning?](01-intro.ipynb)
# 2. [Loss Functions and the Constant Model](02-loss-functions-constant-model.ipynb)
# 3. [Empirical Risk Minimization](03-empirical-risk-minimization.ipynb)
# 4. [Simple Linear Regression](04-simple-linear-regression.ipynb)
# 5. [Least Squares](05-least-squares.ipynb)
