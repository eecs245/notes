# %% [markdown]
# # Chapter 3: Regression using Linear Algebra
#
# Eventually, this chapter will have 3 sections. As these sections are finished, they will be unveiled in the table of contents to the left, and linked directly on the [course website](https://eecs245.org) underneath any relevant lectures.
#
# 1. [Regression using Linear Algebra](./01-regression-using-linear-algebra.ipynb)
# 2. Incorporating Multiple Features
# 3. Overfitting
