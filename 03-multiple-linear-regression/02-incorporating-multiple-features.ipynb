# %% [markdown]
# # 3.2. Incorporating Multiple Features
#
# Incorporating multiple features.
#
# Activity: https://study.practicaldsc.org/wn25-final/index.html
#
# Residual sum to 0 with intercept term
#
# ---
#
# ## Multicollinearity
#
# What if infinitely many best parameter vectors? Still just one best set of predictions
#
# Show that `sklearn` still gives back just one best parameter vector
